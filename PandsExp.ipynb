# %%
import pandas as pd 

df=pd.DataFrame(
    {"Name":["ravi","rk","rk123"],
     "Age":[32,24,57],
     "City":["hyd","bamglore","chennai"]}
)
print(df.columns)
print(df.values)
print(df.tail)
print(df.head)
print(f"\n")
#df[["Name", "Age"] ]  
#df.loc[0]   
#df.iloc[1]
df.loc[0, "City"]    
df.iloc[0, 1]         # specific value
df[df["Age"]<=30]
df["Age"].sort_values
df.sort_values("Age", ascending=False)
df.sort_values("Age")
df.rename(columns={"Name":"Employe Name"})
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')
# [['ravi' 32 'hyd']
#  ['rk' 24 'bamglore']
#  ['rk123' 57 'chennai']]
# <bound method NDFrame.tail of     Name  Age      City
# 0   ravi   32       hyd
# 1     rk   24  bamglore
# 2  rk123   57   chennai>
# <bound method NDFrame.head of     Name  Age      City
# 0   ravi   32       hyd
# 1     rk   24  bamglore
# 2  rk123   57   chennai>
#   Employe Name  Age      City
# 0         ravi   32       hyd
# 1           rk   24  bamglore
# 2        rk123   57   chennai

# %%
import pandas as pd
url ="https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"

df=pd.read_csv(url)
print(df.head(2))
print(df.shape)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# (150, 5)

# %%
pip install sqlalchemy pymysql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sqlalchemy in /Users/rk/Library/Python/3.9/lib/python/site-packages (2.0.48)
# Collecting pymysql
#   Downloading pymysql-1.1.2-py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 1.6 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/rk/Library/Python/3.9/lib/python/site-packages (from sqlalchemy) (4.15.0)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.2
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.
