# %%
# diffrence bw print and f string
# diffrence bw the maketrans and translate
#diffrence bw the replace and substitute
# diffrence bw the strip and rstrip and lstrip
# diffrence bw the center and ljust and rjust
# diffrence bw the replace and translate
# diffrence bw the split and partition
# diffrence bw the capitalize and title
# provide 10 interview question on string and answer with code
# diffrence bw the format and f string
# diffrence bw the upper and lower and swapcase
#` diffrence bw the isalpha and isdigit and isalnum
# Write a Python program to demonstrate the use of string formatting using f-strings. --- IGNORE ---
# write a program on string split and partition
# write a program on string maketrans and translate
# write a program on string replace and substitute
# write a program on string strip and rstrip and lstrip
# write a program on string center and ljust and rjust
# write a program on string replace and translate
# write a program on string split and partition
